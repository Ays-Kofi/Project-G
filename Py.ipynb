# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import csv
import seaborn as sns

# %%
Treenumber = 'datasets/primary.csv'

# %%
Treenumber = pd.read_csv('datasets/primary.csv')

# %%
Treenumber.head()
# Out:
#                Year  Abra  Bataan  Batanes  Batangas  Benguet  Biliran  Bohol
# 0  Year 2011 - 2015   194      29        8         0       49       18     26  \
# 1  Year 2016 - 2020   202       7       92         0       53       42     34
# 2  Year 2021 - 2022   995     184      127         0      338       90    100
#
#   Bukidnon  Bulacan  ... Surigao del Norte  Surigao del Sur Tarlac  Tawi-Tawi
# 0      408      219  ...               257            1,950     12        865  \
# 1      892      147  ...               399            2,836    147      2,288
# 2    1,980      936  ...               887            6,939    177      4,250
#
#    Zambales  Zamboanga del Norte  Aurora  Zamboanga del Sur Zamboanga Sibugay
# 0       127                2,419     424                229               608  \
# 1       240                2,937     204                366               555
# 2       706                8,684   1,862              1,812             2,642
#
#    Basilan
# 0      381
# 1      285
# 2      951
#
# [3 rows x 79 columns]

# %%
description=Treenumber.describe().T
print(description)
# Out:
#                     count        mean         std    min    25%    50%    75%
# Abra                  3.0  463.666667  460.165550  194.0  198.0  202.0  598.5  \
# Bataan                3.0   73.333333   96.469339    7.0   18.0   29.0  106.5
# Batanes               3.0   75.666667   61.158265    8.0   50.0   92.0  109.5
# Batangas              3.0    0.000000    0.000000    0.0    0.0    0.0    0.0
# Benguet               3.0  146.666667  165.711597   49.0   51.0   53.0  195.5
# Biliran               3.0   50.000000   36.660606   18.0   30.0   42.0   66.0
# Bohol                 3.0   53.333333   40.611985   26.0   30.0   34.0   67.0
# Bulacan               3.0  434.000000  436.232736  147.0  183.0  219.0  577.5
# Camarines Norte       3.0  218.666667  198.970685   92.0  104.0  116.0  282.0
# Camarines Sur         3.0  322.333333  255.895161  156.0  175.0  194.0  405.5
# Camiguin              3.0    2.333333    2.081666    0.0    1.5    3.0    3.5
# Capiz                 3.0   46.333333   39.551654   23.0   23.5   24.0   58.0
# Catanduanes           3.0  310.666667  327.359639   78.0  123.5  169.0  427.0
# Cebu                  3.0    0.666667    0.577350    0.0    0.5    1.0    1.0
# Davao del Norte       3.0  346.000000  240.474531  144.0  213.0  282.0  447.0
# Ifugao                3.0  420.666667  335.960315  154.0  232.0  310.0  554.0
# Ilocos Norte          3.0  172.666667  184.819732   61.0   66.0   71.0  228.5
# Ilocos Sur            3.0   14.000000   13.453624    3.0    6.5   10.0   19.5
# Iloilo                3.0   35.333333   39.247081    3.0   13.5   24.0   51.5
# Kalinga               3.0  306.666667  242.289771  115.0  170.5  226.0  402.5
# La Union              3.0    0.333333    0.577350    0.0    0.0    0.0    0.5
# Aklan                 3.0   68.333333   59.676908   29.0   34.0   39.0   88.0
# Laguna                3.0    3.666667    3.511885    0.0    2.0    4.0    5.5
# Marinduque            3.0    0.333333    0.577350    0.0    0.0    0.0    0.5
# Masbate               3.0    2.000000    2.000000    0.0    1.0    2.0    3.0
# Misamis Occidental    3.0   79.000000   72.339477   16.0   39.5   63.0  110.5
# Misamis Oriental      3.0  407.666667  279.466158  157.0  257.0  357.0  533.0
# Albay                 3.0   18.000000   19.078784    6.0    7.0    8.0   24.0
# Mountain Province     3.0  147.666667  126.753041   72.0   74.5   77.0  185.5
# Negros Occidental     3.0   80.333333   79.764236   10.0   37.0   64.0  115.5
# Negros Oriental       3.0   45.666667   42.193996   12.0   22.0   32.0   62.5
# North Cotabato        3.0  435.000000  304.175936  106.0  299.5  493.0  599.5
# Nueva Ecija           3.0  494.666667  392.015731  146.0  282.5  419.0  669.0
# Occidental Mindoro    3.0  320.333333  242.275325  137.0  183.0  229.0  412.0
# Oriental Mindoro      3.0  263.333333  207.138440   86.0  149.5  213.0  352.0
# Antique               3.0   91.333333   90.389896   29.0   39.5   50.0  122.5
# Pampanga              3.0    0.000000    0.000000    0.0    0.0    0.0    0.0
# Pangasinan            3.0   42.333333   41.789153    6.0   19.5   33.0   60.5
# Rizal                 3.0  140.666667  130.346973   37.0   67.5   98.0  192.5
# Romblon               3.0   62.333333   66.583281   19.0   24.0   29.0   84.0
# Siquijor              3.0    0.000000    0.000000    0.0    0.0    0.0    0.0
# Sorsogon              3.0   51.000000   60.753601   12.0   16.0   20.0   70.5
# Southern Leyte        3.0  154.000000  167.609666   45.0   57.5   70.0  208.5
# Sulu                  3.0  185.333333  148.190193   33.0  113.5  194.0  261.5
# Surigao del Norte     3.0  514.333333  330.456250  257.0  328.0  399.0  643.0
# Tarlac                3.0  112.000000   87.891979   12.0   79.5  147.0  162.0
# Zambales              3.0  357.666667  306.910953  127.0  183.5  240.0  473.0
# Basilan               3.0  539.000000  360.016666  285.0  333.0  381.0  666.0
#
#                       max
# Abra                995.0
# Bataan              184.0
# Batanes             127.0
# Batangas              0.0
# Benguet             338.0
# Biliran              90.0
# Bohol               100.0
# Bulacan             936.0
# Camarines Norte     448.0
# Camarines Sur       617.0
# Camiguin              4.0
# Capiz                92.0
# Catanduanes         685.0
# Cebu                  1.0
# Davao del Norte     612.0
# Ifugao              798.0
# Ilocos Norte        386.0
# Ilocos Sur           29.0
# Iloilo               79.0
# Kalinga             579.0
# La Union              1.0
# Aklan               137.0
# Laguna                7.0
# Marinduque            1.0
# Masbate               4.0
# Misamis Occidental  158.0
# Misamis Oriental    709.0
# Albay                40.0
# Mountain Province   294.0
# Negros Occidental   167.0
# Negros Oriental      93.0
# North Cotabato      706.0
# Nueva Ecija         919.0
# Occidental Mindoro  595.0
# Oriental Mindoro    491.0
# Antique             195.0
# Pampanga              0.0
# Pangasinan           88.0
# Rizal               287.0
# Romblon             139.0
# Siquijor              0.0
# Sorsogon            121.0
# Southern Leyte      347.0
# Sulu                329.0
# Surigao del Norte   887.0
# Tarlac              177.0
# Zambales            706.0
# Basilan             951.0

# %%
plt.figure(figsize=(12, 8))

plt.bar(Treenumber['Year'], Treenumber['Eastern Samar'], color=['#fbf8cc', '#ffcfd2', '#cfbaf0', '#a3c4f3', '#90dbf4', '#8eecf5', '#98f5e1', '#b9fbc0'])

plt.title("Land Cover of the Philippines in year 2011 to 2019")
plt.xlabel('Year', fontsize=14)
plt.ylabel('Eastern Samar', fontsize=14)
plt.grid(True)

plt.show()

# %%
description = Treenumber.describe()
plt.figure(figsize=(12, 8))

description.loc['mean'].plot(kind='bar')

plt.xlabel('Columns')
plt.ylabel('Mean')
plt.title('Mean Values of Columns')

plt.show()

# %%
description = Treenumber.describe()

# Extract the statistics you want to visualize
statistics = description.loc[['count', 'mean', 'std', 'min', '25%', '50%']]

# Transpose the DataFrame for easier plotting
statistics = statistics.T

# Adjust figure size
plt.figure(figsize=(12, 8))

# Plotting the line graph
statistics.plot(kind='line', marker='o')

# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('Value')
plt.title('Descriptive Statistics')

# Adjust font size
plt.xticks(range(len(statistics.index)), statistics.index, fontsize=8)
plt.xticks(rotation=90)
# Display the plot
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))                                                                         

plt.title('Tree Cover of Phillipines in year of 2012 to 2019')       

for year in Treenumber:                                                                      
    plt.plot(Treenumber[year], label=year, marker = 'h')

                                           
plt.xlabel('Year', fontsize=11)                                                               

plt.legend(loc='upper center', bbox_to_anchor=(1.19, .8))                                          
plt.show()
